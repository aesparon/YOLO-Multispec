# %% [markdown]
# # 🧠 YOLO-MultiSpec: Demo Notebook
#
# ## 🔍 Section 1: Introduction
#
# This notebook demonstrates how to load a modified YOLO model for 4-channel multispectral input, run inference, and export it to ONNX for visualization and deployment.
#
# ---
#
# ## ⚙️ Step 1: Setup Environment
#
# Below we install dependencies and clone the YOLO-MultiSpec repository.

# %%
# !python --version
# Out:
# Python 3.10.18

# %%
# !git clone https://github.com/aesparon/YOLO-Multispec.git
# Out:
# fatal: destination path 'YOLO-Multispec' already exists and is not an empty directory.

# %%
# !pip install -r requirements.txt

# %%
# ✅ Install YOLO and other requirements
# !pip install ultralytics torch torchvision --quiet

# ⬇️ Clone your repo (replace with actual repo)
# !git clone https://github.com/aesparon/YOLO-MultiSpec.git
# %cd YOLO-MultiSpec
# Out:
# d:\PD\Publications\Yolo_mod\github\YOLO-Multispec\examples\notebooks\YOLO-MultiSpec\YOLO-MultiSpec
# Cloning into 'YOLO-MultiSpec'...

# %%
# !git clone https://github.com/aesparon/YOLO-Multispec.git
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# Cloning into 'YOLO-Multispec'...

# %%
from utils.mod_pt_model import CBAM, ECA

print("Modules imported successfully!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from utils.mod_pt_model import CBAM, ECA
#       3 print("Modules imported successfully!")
#
# ModuleNotFoundError: No module named 'utils'

# %%
# Cell 3: Example of running training script
# !python train_evaluate.py --data data.yaml --imgsz 1024 --epochs 10 --device 0
